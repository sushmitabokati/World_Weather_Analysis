# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime
import requests
from config import *
from citipy import citipy

# %%
weather_api_keys
# Out:
# 'fe33f7765c16411c8f1457004f5942c1'

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_keys
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=fe33f7765c16411c8f1457004f5942c1

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
#Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i>=50):
        set_count += 1
        record_count = 1
        
    #Create endpoint url for each city.
    city_url = url + "&q=" + city
        
    #log the url,record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        
    #Add 1 to the record count.
    record_count += 1
        
    #Run an API request for each of the cities.
    try:
         #Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
            
            
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                            "Lat": city_lat,
                             "Lng": city_lng,
                             "Max Temp": city_max_temp,
                             "Humidity": city_humidity,
                             "Cloudiness": city_clouds,
                             "Wind Speed": city_wind,                                                         
                             "Current Description":city_weather_description
                              })
    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
#Indicate the data loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | escanaba
# Processing Record 2 of Set 1 | stonewall
# Processing Record 3 of Set 1 | east london
# Processing Record 4 of Set 1 | sao filipe
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | isangel
# Processing Record 7 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 1 | khatanga
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | bintulu
# Processing Record 11 of Set 1 | comodoro rivadavia
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | commerce
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 1 | upernavik
# Processing Record 17 of Set 1 | tondano
# Processing Record 18 of Set 1 | nanuque
# Processing Record 19 of Set 1 | ahipara
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | saint george
# Processing Record 22 of Set 1 | new norfolk
# Processing Record 23 of Set 1 | georgetown
# Processing Record 24 of Set 1 | souillac
# Processing Record 25 of Set 1 | castro
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | havelock
# Processing Record 28 of Set 1 | ornskoldsvik
# Processing Record 29 of Set 1 | semirom
# Processing Record 30 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 31 of Set 1 | qaanaaq
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | manokwari
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | tsienyane
# City not found. Skipping...
# Processing Record 38 of Set 1 | nikolskoye
# Processing Record 39 of Set 1 | provideniya
# Processing Record 40 of Set 1 | butaritari
# Processing Record 41 of Set 1 | inirida
# Processing Record 42 of Set 1 | havoysund
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | kieta
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | bambous virieux
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | santa cruz de tenerife
# Processing Record 49 of Set 1 | awjilah
# Processing Record 50 of Set 1 | limoeiro de anadia
# Processing Record 1 of Set 2 | isla vista
# Processing Record 2 of Set 2 | quba
# Processing Record 3 of Set 2 | kanye
# Processing Record 4 of Set 2 | zeya
# Processing Record 5 of Set 2 | cayenne
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | hilo
# Processing Record 8 of Set 2 | lensk
# Processing Record 9 of Set 2 | yar-sale
# Processing Record 10 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 2 | kunya
# Processing Record 12 of Set 2 | college
# Processing Record 13 of Set 2 | sagarejo
# Processing Record 14 of Set 2 | constantine
# Processing Record 15 of Set 2 | baytown
# Processing Record 16 of Set 2 | mar del plata
# Processing Record 17 of Set 2 | san cristobal
# Processing Record 18 of Set 2 | sisimiut
# Processing Record 19 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 20 of Set 2 | salalah
# Processing Record 21 of Set 2 | san policarpo
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | ituni
# City not found. Skipping...
# Processing Record 24 of Set 2 | baykit
# Processing Record 25 of Set 2 | korgen
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | bethel
# Processing Record 28 of Set 2 | geraldton
# Processing Record 29 of Set 2 | hare bay
# Processing Record 30 of Set 2 | pelym
# Processing Record 31 of Set 2 | bandarbeyla
# Processing Record 32 of Set 2 | bluff
# Processing Record 33 of Set 2 | blonduos
# City not found. Skipping...
# Processing Record 34 of Set 2 | jamestown
# Processing Record 35 of Set 2 | dom pedrito
# Processing Record 36 of Set 2 | zastron
# Processing Record 37 of Set 2 | poum
# Processing Record 38 of Set 2 | dunedin
# Processing Record 39 of Set 2 | oderzo
# Processing Record 40 of Set 2 | marang
# Processing Record 41 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 2 | banita
# Processing Record 43 of Set 2 | saskylakh
# Processing Record 44 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 2 | roma
# Processing Record 46 of Set 2 | alenquer
# Processing Record 47 of Set 2 | kapaa
# Processing Record 48 of Set 2 | northam
# Processing Record 49 of Set 2 | carnarvon
# Processing Record 50 of Set 2 | gotsu
# Processing Record 1 of Set 3 | chokurdakh
# Processing Record 2 of Set 3 | itaituba
# Processing Record 3 of Set 3 | abonnema
# Processing Record 4 of Set 3 | luangwa
# Processing Record 5 of Set 3 | torbay
# Processing Record 6 of Set 3 | kumbo
# Processing Record 7 of Set 3 | cape canaveral
# Processing Record 8 of Set 3 | itapaci
# Processing Record 9 of Set 3 | portland
# Processing Record 10 of Set 3 | srednekolymsk
# Processing Record 11 of Set 3 | guerrero negro
# Processing Record 12 of Set 3 | katobu
# Processing Record 13 of Set 3 | carroll
# Processing Record 14 of Set 3 | muros
# Processing Record 15 of Set 3 | ribeira grande
# Processing Record 16 of Set 3 | tuktoyaktuk
# Processing Record 17 of Set 3 | atambua
# Processing Record 18 of Set 3 | romanovka
# Processing Record 19 of Set 3 | antalaha
# Processing Record 20 of Set 3 | leua
# Processing Record 21 of Set 3 | barrow
# Processing Record 22 of Set 3 | malindi
# Processing Record 23 of Set 3 | dikson
# Processing Record 24 of Set 3 | aksarka
# Processing Record 25 of Set 3 | nome
# Processing Record 26 of Set 3 | tasiilaq
# Processing Record 27 of Set 3 | lebu
# Processing Record 28 of Set 3 | mount hagen
# Processing Record 29 of Set 3 | pochutla
# Processing Record 30 of Set 3 | tapaua
# City not found. Skipping...
# Processing Record 31 of Set 3 | san fernando
# Processing Record 32 of Set 3 | chuy
# Processing Record 33 of Set 3 | rayong
# Processing Record 34 of Set 3 | bolgar
# Processing Record 35 of Set 3 | kropotkin
# Processing Record 36 of Set 3 | bairiki
# Processing Record 37 of Set 3 | alice springs
# Processing Record 38 of Set 3 | lata
# Processing Record 39 of Set 3 | dhandhuka
# Processing Record 40 of Set 3 | pisco
# Processing Record 41 of Set 3 | avarua
# Processing Record 42 of Set 3 | port hueneme
# Processing Record 43 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 3 | victoria
# Processing Record 45 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 3 | port lincoln
# Processing Record 47 of Set 3 | ilulissat
# Processing Record 48 of Set 3 | ciudad bolivar
# Processing Record 49 of Set 3 | la rioja
# Processing Record 50 of Set 3 | kenora
# Processing Record 1 of Set 4 | sao joao da barra
# Processing Record 2 of Set 4 | gat
# Processing Record 3 of Set 4 | aykino
# Processing Record 4 of Set 4 | veraval
# Processing Record 5 of Set 4 | talnakh
# Processing Record 6 of Set 4 | nanortalik
# Processing Record 7 of Set 4 | cidreira
# Processing Record 8 of Set 4 | kamina
# Processing Record 9 of Set 4 | te anau
# Processing Record 10 of Set 4 | sabang
# Processing Record 11 of Set 4 | tuatapere
# Processing Record 12 of Set 4 | sungaipenuh
# Processing Record 13 of Set 4 | aguimes
# Processing Record 14 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 4 | caravelas
# Processing Record 16 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 4 | awbari
# Processing Record 18 of Set 4 | severo-kurilsk
# Processing Record 19 of Set 4 | diapaga
# Processing Record 20 of Set 4 | fortuna
# Processing Record 21 of Set 4 | hamilton
# Processing Record 22 of Set 4 | port hardy
# Processing Record 23 of Set 4 | arraial do cabo
# Processing Record 24 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 25 of Set 4 | zhangye
# Processing Record 26 of Set 4 | thompson
# Processing Record 27 of Set 4 | yeppoon
# Processing Record 28 of Set 4 | mehamn
# Processing Record 29 of Set 4 | misratah
# Processing Record 30 of Set 4 | inverell
# Processing Record 31 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 4 | dekoa
# City not found. Skipping...
# Processing Record 33 of Set 4 | shaunavon
# Processing Record 34 of Set 4 | mount isa
# Processing Record 35 of Set 4 | mahebourg
# Processing Record 36 of Set 4 | lumberton
# Processing Record 37 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 4 | ancud
# Processing Record 39 of Set 4 | pevek
# Processing Record 40 of Set 4 | byron bay
# Processing Record 41 of Set 4 | aars
# Processing Record 42 of Set 4 | shingu
# Processing Record 43 of Set 4 | yaan
# Processing Record 44 of Set 4 | batemans bay
# Processing Record 45 of Set 4 | lanigan
# Processing Record 46 of Set 4 | port elizabeth
# Processing Record 47 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 48 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 4 | touros
# Processing Record 50 of Set 4 | padang
# Processing Record 1 of Set 5 | port macquarie
# Processing Record 2 of Set 5 | grindavik
# Processing Record 3 of Set 5 | olafsvik
# Processing Record 4 of Set 5 | kavieng
# Processing Record 5 of Set 5 | okha
# Processing Record 6 of Set 5 | esperance
# Processing Record 7 of Set 5 | teguldet
# Processing Record 8 of Set 5 | aripuana
# Processing Record 9 of Set 5 | parrita
# Processing Record 10 of Set 5 | coquimbo
# Processing Record 11 of Set 5 | rio cuarto
# Processing Record 12 of Set 5 | muroto
# Processing Record 13 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 5 | clyde river
# Processing Record 15 of Set 5 | mildura
# Processing Record 16 of Set 5 | neiafu
# Processing Record 17 of Set 5 | state college
# Processing Record 18 of Set 5 | santa rosa de aguan
# Processing Record 19 of Set 5 | ponta do sol
# Processing Record 20 of Set 5 | manggar
# Processing Record 21 of Set 5 | port said
# Processing Record 22 of Set 5 | caceres
# Processing Record 23 of Set 5 | gidole
# Processing Record 24 of Set 5 | korla
# Processing Record 25 of Set 5 | bartica
# Processing Record 26 of Set 5 | hofn
# Processing Record 27 of Set 5 | zhanaozen
# Processing Record 28 of Set 5 | czarnkow
# Processing Record 29 of Set 5 | longyearbyen
# Processing Record 30 of Set 5 | fuxin
# Processing Record 31 of Set 5 | gumdag
# Processing Record 32 of Set 5 | vila franca do campo
# Processing Record 33 of Set 5 | bonthe
# Processing Record 34 of Set 5 | flinders
# Processing Record 35 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 5 | sawang daen din
# Processing Record 37 of Set 5 | hasaki
# Processing Record 38 of Set 5 | iskateley
# Processing Record 39 of Set 5 | mwanza
# Processing Record 40 of Set 5 | oussouye
# Processing Record 41 of Set 5 | sanok
# Processing Record 42 of Set 5 | narsaq
# Processing Record 43 of Set 5 | taltal
# Processing Record 44 of Set 5 | mirnyy
# Processing Record 45 of Set 5 | mackay
# Processing Record 46 of Set 5 | la huacana
# Processing Record 47 of Set 5 | culebra
# Processing Record 48 of Set 5 | phan thiet
# Processing Record 49 of Set 5 | sorong
# Processing Record 50 of Set 5 | constitucion
# Processing Record 1 of Set 6 | faanui
# Processing Record 2 of Set 6 | old saybrook
# Processing Record 3 of Set 6 | thaba-tseka
# Processing Record 4 of Set 6 | mecca
# Processing Record 5 of Set 6 | mount gambier
# Processing Record 6 of Set 6 | tecpan
# Processing Record 7 of Set 6 | arman
# Processing Record 8 of Set 6 | lyambir
# Processing Record 9 of Set 6 | visby
# Processing Record 10 of Set 6 | sakakah
# Processing Record 11 of Set 6 | monterey
# Processing Record 12 of Set 6 | jumla
# Processing Record 13 of Set 6 | dawlatabad
# Processing Record 14 of Set 6 | filadelfia
# Processing Record 15 of Set 6 | jiwani
# Processing Record 16 of Set 6 | pemangkat
# Processing Record 17 of Set 6 | abu samrah
# Processing Record 18 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 6 | whitehaven
# Processing Record 20 of Set 6 | itarema
# Processing Record 21 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 22 of Set 6 | kabanjahe
# Processing Record 23 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 6 | vestmanna
# Processing Record 25 of Set 6 | grand gaube
# Processing Record 26 of Set 6 | ereymentau
# Processing Record 27 of Set 6 | cabo san lucas
# Processing Record 28 of Set 6 | soke
# Processing Record 29 of Set 6 | berlevag
# Processing Record 30 of Set 6 | mayma
# Processing Record 31 of Set 6 | okitipupa
# Processing Record 32 of Set 6 | tukrah
# Processing Record 33 of Set 6 | mnogovershinnyy
# Processing Record 34 of Set 6 | kiruna
# Processing Record 35 of Set 6 | ignacio de la llave
# Processing Record 36 of Set 6 | sussex
# Processing Record 37 of Set 6 | asau
# Processing Record 38 of Set 6 | hami
# Processing Record 39 of Set 6 | satuba
# Processing Record 40 of Set 6 | zarate
# Processing Record 41 of Set 6 | mandalgovi
# Processing Record 42 of Set 6 | rawson
# Processing Record 43 of Set 6 | springbok
# Processing Record 44 of Set 6 | kloulklubed
# Processing Record 45 of Set 6 | luderitz
# Processing Record 46 of Set 6 | sambava
# Processing Record 47 of Set 6 | hualmay
# Processing Record 48 of Set 6 | zaraza
# Processing Record 49 of Set 6 | tulum
# Processing Record 50 of Set 6 | axim
# Processing Record 1 of Set 7 | igrim
# Processing Record 2 of Set 7 | jiuquan
# Processing Record 3 of Set 7 | minab
# Processing Record 4 of Set 7 | vila velha
# Processing Record 5 of Set 7 | adrar
# Processing Record 6 of Set 7 | brugelette
# Processing Record 7 of Set 7 | helena
# Processing Record 8 of Set 7 | alofi
# Processing Record 9 of Set 7 | inyonga
# Processing Record 10 of Set 7 | sitka
# Processing Record 11 of Set 7 | bilibino
# Processing Record 12 of Set 7 | saint-augustin
# Processing Record 13 of Set 7 | kem
# Processing Record 14 of Set 7 | bumba
# Processing Record 15 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 7 | forestville
# Processing Record 17 of Set 7 | de-kastri
# Processing Record 18 of Set 7 | auki
# Processing Record 19 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 7 | lingao
# Processing Record 21 of Set 7 | zemio
# Processing Record 22 of Set 7 | sacramento
# Processing Record 23 of Set 7 | sorland
# Processing Record 24 of Set 7 | lagoa
# Processing Record 25 of Set 7 | urusha
# Processing Record 26 of Set 7 | katsuura
# Processing Record 27 of Set 7 | tura
# Processing Record 28 of Set 7 | husavik
# Processing Record 29 of Set 7 | newark
# Processing Record 30 of Set 7 | huarmey
# Processing Record 31 of Set 7 | lukaya
# Processing Record 32 of Set 7 | kaitangata
# Processing Record 33 of Set 7 | pedra azul
# Processing Record 34 of Set 7 | marawi
# Processing Record 35 of Set 7 | sabha
# Processing Record 36 of Set 7 | kingaroy
# Processing Record 37 of Set 7 | ketchikan
# Processing Record 38 of Set 7 | port blair
# Processing Record 39 of Set 7 | sovetskaya gavan
# Processing Record 40 of Set 7 | ukmerge
# Processing Record 41 of Set 7 | leningradskiy
# Processing Record 42 of Set 7 | egvekinot
# Processing Record 43 of Set 7 | nikel
# Processing Record 44 of Set 7 | siderno
# Processing Record 45 of Set 7 | lazaro cardenas
# Processing Record 46 of Set 7 | masyaf
# Processing Record 47 of Set 7 | kapit
# Processing Record 48 of Set 7 | bingol
# Processing Record 49 of Set 7 | natal
# Processing Record 50 of Set 7 | bayji
# Processing Record 1 of Set 8 | ocos
# Processing Record 2 of Set 8 | saint-philippe
# Processing Record 3 of Set 8 | opotiki
# Processing Record 4 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 8 | cervo
# Processing Record 6 of Set 8 | seymchan
# Processing Record 7 of Set 8 | ritchie
# Processing Record 8 of Set 8 | flensburg
# Processing Record 9 of Set 8 | harper
# Processing Record 10 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 11 of Set 8 | dongfeng
# Processing Record 12 of Set 8 | emerald
# Processing Record 13 of Set 8 | namibe
# Processing Record 14 of Set 8 | port-gentil
# Processing Record 15 of Set 8 | lorengau
# Processing Record 16 of Set 8 | coihaique
# Processing Record 17 of Set 8 | komsomolskiy
# Processing Record 18 of Set 8 | maniitsoq
# Processing Record 19 of Set 8 | cap-aux-meules
# Processing Record 20 of Set 8 | kutum
# Processing Record 21 of Set 8 | sao paulo de olivenca
# Processing Record 22 of Set 8 | torata
# Processing Record 23 of Set 8 | show low
# Processing Record 24 of Set 8 | pangnirtung
# Processing Record 25 of Set 8 | ocean springs
# Processing Record 26 of Set 8 | elliot lake
# Processing Record 27 of Set 8 | mabaruma
# Processing Record 28 of Set 8 | santa isabel
# Processing Record 29 of Set 8 | santa marta
# Processing Record 30 of Set 8 | sulechow
# Processing Record 31 of Set 8 | port hedland
# Processing Record 32 of Set 8 | quelimane
# Processing Record 33 of Set 8 | barcelos
# Processing Record 34 of Set 8 | umm kaddadah
# Processing Record 35 of Set 8 | matara
# Processing Record 36 of Set 8 | jati
# Processing Record 37 of Set 8 | jaen
# Processing Record 38 of Set 8 | arkhangelsk
# Processing Record 39 of Set 8 | namatanai
# Processing Record 40 of Set 8 | porto belo
# Processing Record 41 of Set 8 | bengkulu
# Processing Record 42 of Set 8 | norman wells
# Processing Record 43 of Set 8 | abeokuta
# Processing Record 44 of Set 8 | bilma
# Processing Record 45 of Set 8 | burns lake
# Processing Record 46 of Set 8 | oriximina
# Processing Record 47 of Set 8 | kattivakkam
# Processing Record 48 of Set 8 | birao
# Processing Record 49 of Set 8 | ferme-neuve
# Processing Record 50 of Set 8 | johnstown
# Processing Record 1 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 2 of Set 9 | nizhniy kuranakh
# Processing Record 3 of Set 9 | kalemie
# Processing Record 4 of Set 9 | belyy yar
# Processing Record 5 of Set 9 | ixtapa
# Processing Record 6 of Set 9 | makakilo city
# Processing Record 7 of Set 9 | raudeberg
# Processing Record 8 of Set 9 | kushmurun
# Processing Record 9 of Set 9 | karasjok
# Processing Record 10 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 11 of Set 9 | mogadishu
# Processing Record 12 of Set 9 | colares
# Processing Record 13 of Set 9 | tara
# Processing Record 14 of Set 9 | kolyvan
# Processing Record 15 of Set 9 | acapulco
# Processing Record 16 of Set 9 | tiksi
# Processing Record 17 of Set 9 | rheinbach
# Processing Record 18 of Set 9 | beringovskiy
# Processing Record 19 of Set 9 | makasar
# Processing Record 20 of Set 9 | hithadhoo
# Processing Record 21 of Set 9 | taganak
# Processing Record 22 of Set 9 | nishihara
# Processing Record 23 of Set 9 | karratha
# Processing Record 24 of Set 9 | prince rupert
# Processing Record 25 of Set 9 | novikovo
# Processing Record 26 of Set 9 | nemuro
# Processing Record 27 of Set 9 | aden
# Processing Record 28 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 9 | si chiang mai
# Processing Record 30 of Set 9 | aksu
# Processing Record 31 of Set 9 | hambantota
# Processing Record 32 of Set 9 | cam ranh
# Processing Record 33 of Set 9 | conselheiro pena
# Processing Record 34 of Set 9 | marystown
# Processing Record 35 of Set 9 | monrovia
# Processing Record 36 of Set 9 | bafq
# Processing Record 37 of Set 9 | vardo
# Processing Record 38 of Set 9 | paamiut
# Processing Record 39 of Set 9 | san ramon
# Processing Record 40 of Set 9 | kavaratti
# Processing Record 41 of Set 9 | quang ngai
# Processing Record 42 of Set 9 | kembe
# Processing Record 43 of Set 9 | areia branca
# Processing Record 44 of Set 9 | ternate
# Processing Record 45 of Set 9 | ayan
# Processing Record 46 of Set 9 | verkhnyaya toyma
# Processing Record 47 of Set 9 | angoche
# Processing Record 48 of Set 9 | boyuibe
# Processing Record 49 of Set 9 | bakchar
# Processing Record 50 of Set 9 | la asuncion
# Processing Record 1 of Set 10 | miles city
# Processing Record 2 of Set 10 | bima
# Processing Record 3 of Set 10 | markivka
# Processing Record 4 of Set 10 | dingle
# Processing Record 5 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 10 | aitape
# Processing Record 7 of Set 10 | margate
# Processing Record 8 of Set 10 | kewanee
# Processing Record 9 of Set 10 | faranah
# Processing Record 10 of Set 10 | sanming
# Processing Record 11 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 10 | talara
# Processing Record 13 of Set 10 | fairbanks
# Processing Record 14 of Set 10 | tres arroyos
# Processing Record 15 of Set 10 | tari
# Processing Record 16 of Set 10 | banda aceh
# Processing Record 17 of Set 10 | storm lake
# Processing Record 18 of Set 10 | batagay
# Processing Record 19 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 20 of Set 10 | yumen
# Processing Record 21 of Set 10 | buala
# Processing Record 22 of Set 10 | kahului
# Processing Record 23 of Set 10 | charters towers
# Processing Record 24 of Set 10 | sao felix do xingu
# Processing Record 25 of Set 10 | pacific grove
# Processing Record 26 of Set 10 | kuybysheve
# Processing Record 27 of Set 10 | kruisfontein
# Processing Record 28 of Set 10 | dembi dolo
# Processing Record 29 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 10 | san miguel
# Processing Record 31 of Set 10 | najran
# Processing Record 32 of Set 10 | selkirk
# Processing Record 33 of Set 10 | tadine
# Processing Record 34 of Set 10 | stamsund
# City not found. Skipping...
# Processing Record 35 of Set 10 | borogontsy
# Processing Record 36 of Set 10 | senanga
# Processing Record 37 of Set 10 | wisconsin rapids
# Processing Record 38 of Set 10 | vilhena
# Processing Record 39 of Set 10 | qianan
# Processing Record 40 of Set 10 | chikoy
# City not found. Skipping...
# Processing Record 41 of Set 10 | linchuan
# City not found. Skipping...
# Processing Record 42 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 43 of Set 10 | poso
# Processing Record 44 of Set 10 | kawalu
# Processing Record 45 of Set 10 | chengmai
# City not found. Skipping...
# Processing Record 46 of Set 10 | altamont
# Processing Record 47 of Set 10 | hirara
# Processing Record 48 of Set 10 | north bend
# Processing Record 49 of Set 10 | san juan
# Processing Record 50 of Set 10 | zyryanka
# Processing Record 1 of Set 11 | hobyo
# Processing Record 2 of Set 11 | strezhevoy
# Processing Record 3 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 5 of Set 11 | pachino
# Processing Record 6 of Set 11 | maldonado
# Processing Record 7 of Set 11 | labuhan
# Processing Record 8 of Set 11 | ust-uda
# Processing Record 9 of Set 11 | khandyga
# Processing Record 10 of Set 11 | daru
# Processing Record 11 of Set 11 | silivri
# Processing Record 12 of Set 11 | stulovo
# Processing Record 13 of Set 11 | chama
# Processing Record 14 of Set 11 | sadri
# Processing Record 15 of Set 11 | iberia
# Processing Record 16 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 17 of Set 11 | lodeynoye pole
# Processing Record 18 of Set 11 | buraydah
# Processing Record 19 of Set 11 | mirabad
# Processing Record 20 of Set 11 | puerto del rosario
# Processing Record 21 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 22 of Set 11 | gigmoto
# Processing Record 23 of Set 11 | altay
# Processing Record 24 of Set 11 | maymyo
# Processing Record 25 of Set 11 | jesus del monte
# Processing Record 26 of Set 11 | ribas do rio pardo
# Processing Record 27 of Set 11 | san isidro
# Processing Record 28 of Set 11 | saint pete beach
# Processing Record 29 of Set 11 | naranjal
# Processing Record 30 of Set 11 | edenderry
# Processing Record 31 of Set 11 | tommot
# Processing Record 32 of Set 11 | maragogi
# Processing Record 33 of Set 11 | macenta
# Processing Record 34 of Set 11 | kemijarvi
# Processing Record 35 of Set 11 | matamoros
# Processing Record 36 of Set 11 | cherskiy
# Processing Record 37 of Set 11 | semey
# Processing Record 38 of Set 11 | saldanha
# Processing Record 39 of Set 11 | murray bridge
# Processing Record 40 of Set 11 | fort frances
# Processing Record 41 of Set 11 | darnah
# Processing Record 42 of Set 11 | vostok
# Processing Record 43 of Set 11 | ust-ishim
# Processing Record 44 of Set 11 | sikasso
# Processing Record 45 of Set 11 | bandar-e lengeh
# Processing Record 46 of Set 11 | shakiso
# Processing Record 47 of Set 11 | buin
# Processing Record 48 of Set 11 | trinidad
# Processing Record 49 of Set 11 | aktash
# Processing Record 50 of Set 11 | birjand
# Processing Record 1 of Set 12 | sinegorskiy
# Processing Record 2 of Set 12 | sedalia
# Processing Record 3 of Set 12 | hay river
# Processing Record 4 of Set 12 | japura
# Processing Record 5 of Set 12 | avera
# Processing Record 6 of Set 12 | alausi
# Processing Record 7 of Set 12 | luganville
# Processing Record 8 of Set 12 | dajal
# Processing Record 9 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 10 of Set 12 | bage
# Processing Record 11 of Set 12 | juba
# Processing Record 12 of Set 12 | payo
# Processing Record 13 of Set 12 | kununurra
# Processing Record 14 of Set 12 | haines junction
# Processing Record 15 of Set 12 | stornoway
# Processing Record 16 of Set 12 | port-cartier
# Processing Record 17 of Set 12 | gardan diwal
# City not found. Skipping...
# Processing Record 18 of Set 12 | san patricio
# Processing Record 19 of Set 12 | okhotsk
# Processing Record 20 of Set 12 | tabuk
# Processing Record 21 of Set 12 | jaguaribe
# Processing Record 22 of Set 12 | la candelaria
# Processing Record 23 of Set 12 | ashwaubenon
# Processing Record 24 of Set 12 | beloha
# Processing Record 25 of Set 12 | karaton
# Processing Record 26 of Set 12 | danville
# Processing Record 27 of Set 12 | karymskoye
# Processing Record 28 of Set 12 | diamantino
# Processing Record 29 of Set 12 | chivay
# Processing Record 30 of Set 12 | alindao
# Processing Record 31 of Set 12 | lumeje
# Processing Record 32 of Set 12 | airai
# Processing Record 33 of Set 12 | seoul
# Processing Record 34 of Set 12 | krasnoselkup
# Processing Record 35 of Set 12 | moron
# Processing Record 36 of Set 12 | licheng
# Processing Record 37 of Set 12 | semnan
# Processing Record 38 of Set 12 | puerto escondido
# Processing Record 39 of Set 12 | lavrentiya
# Processing Record 40 of Set 12 | pangody
# Processing Record 41 of Set 12 | la ronge
# Processing Record 42 of Set 12 | westport
# Processing Record 43 of Set 12 | iquique
# Processing Record 44 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 45 of Set 12 | palmer
# Processing Record 46 of Set 12 | appenzell
# Processing Record 47 of Set 12 | sebinkarahisar
# Processing Record 48 of Set 12 | brae
# Processing Record 49 of Set 12 | taiyuan
# Processing Record 50 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 1 of Set 13 | loubomo
# Processing Record 2 of Set 13 | belaya gora
# Processing Record 3 of Set 13 | nuuk
# Processing Record 4 of Set 13 | usinsk
# Processing Record 5 of Set 13 | khasan
# Processing Record 6 of Set 13 | jablanica
# Processing Record 7 of Set 13 | tromso
# Processing Record 8 of Set 13 | shache
# Processing Record 9 of Set 13 | rostaq
# City not found. Skipping...
# Processing Record 10 of Set 13 | samana
# Processing Record 11 of Set 13 | novoagansk
# Processing Record 12 of Set 13 | myanaung
# Processing Record 13 of Set 13 | milkovo
# Processing Record 14 of Set 13 | outlook
# Processing Record 15 of Set 13 | khrebtovaya
# Processing Record 16 of Set 13 | gorontalo
# Processing Record 17 of Set 13 | miyazu
# Processing Record 18 of Set 13 | biltine
# Processing Record 19 of Set 13 | weihai
# Processing Record 20 of Set 13 | helong
# Processing Record 21 of Set 13 | ushtobe
# Processing Record 22 of Set 13 | gasa
# Processing Record 23 of Set 13 | hovd
# Processing Record 24 of Set 13 | toktogul
# Processing Record 25 of Set 13 | flin flon
# Processing Record 26 of Set 13 | benghazi
# Processing Record 27 of Set 13 | dali
# Processing Record 28 of Set 13 | itoman
# Processing Record 29 of Set 13 | lompoc
# Processing Record 30 of Set 13 | general pico
# Processing Record 31 of Set 13 | fukue
# Processing Record 32 of Set 13 | broome
# Processing Record 33 of Set 13 | zhigansk
# Processing Record 34 of Set 13 | chulym
# Processing Record 35 of Set 13 | laramie
# Processing Record 36 of Set 13 | progreso
# Processing Record 37 of Set 13 | lonar
# Processing Record 38 of Set 13 | mykolayivka
# Processing Record 39 of Set 13 | altamira
# Processing Record 40 of Set 13 | houma
# Processing Record 41 of Set 13 | salima
# Processing Record 42 of Set 13 | alta floresta
# Processing Record 43 of Set 13 | yenotayevka
# Processing Record 44 of Set 13 | moose factory
# Processing Record 45 of Set 13 | moura
# Processing Record 46 of Set 13 | oksfjord
# Processing Record 47 of Set 13 | faya
# Processing Record 48 of Set 13 | chongqing
# Processing Record 49 of Set 13 | maryborough
# Processing Record 50 of Set 13 | buchanan
# Processing Record 1 of Set 14 | soyo
# Processing Record 2 of Set 14 | aklavik
# Processing Record 3 of Set 14 | cooma
# Processing Record 4 of Set 14 | penzance
# Processing Record 5 of Set 14 | el dorado
# Processing Record 6 of Set 14 | aykhal
# Processing Record 7 of Set 14 | merauke
# Processing Record 8 of Set 14 | santa rosa
# Processing Record 9 of Set 14 | ardistan
# City not found. Skipping...
# Processing Record 10 of Set 14 | yelovo
# Processing Record 11 of Set 14 | otradnoye
# Processing Record 12 of Set 14 | grand island
# Processing Record 13 of Set 14 | edremit
# Processing Record 14 of Set 14 | honiara
# Processing Record 15 of Set 14 | cockburn town
# Processing Record 16 of Set 14 | matay
# Processing Record 17 of Set 14 | montepuez
# Processing Record 18 of Set 14 | lady frere
# Processing Record 19 of Set 14 | kholodnyy
# Processing Record 20 of Set 14 | iqaluit
# Processing Record 21 of Set 14 | cardston
# Processing Record 22 of Set 14 | lindi
# Processing Record 23 of Set 14 | one hundred mile house
# City not found. Skipping...
# Processing Record 24 of Set 14 | maceio
# Processing Record 25 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 14 | ust-kulom
# Processing Record 27 of Set 14 | pampa
# Processing Record 28 of Set 14 | rovaniemi
# Processing Record 29 of Set 14 | turukhansk
# Processing Record 30 of Set 14 | bol
# Processing Record 31 of Set 14 | grafton
# Processing Record 32 of Set 14 | tautira
# Processing Record 33 of Set 14 | mount pleasant
# Processing Record 34 of Set 14 | shenjiamen
# Processing Record 35 of Set 14 | lalomanu
# City not found. Skipping...
# Processing Record 36 of Set 14 | wroclaw
# Processing Record 37 of Set 14 | marseille
# Processing Record 38 of Set 14 | nantucket
# Processing Record 39 of Set 14 | kansk
# Processing Record 40 of Set 14 | hyeres
# Processing Record 41 of Set 14 | tokur
# Processing Record 42 of Set 14 | olinda
# Processing Record 43 of Set 14 | ponta delgada
# Processing Record 44 of Set 14 | burkhala
# City not found. Skipping...
# Processing Record 45 of Set 14 | bushehr
# Processing Record 46 of Set 14 | norrkoping
# Processing Record 47 of Set 14 | urengoy
# Processing Record 48 of Set 14 | lianzhou
# Processing Record 49 of Set 14 | hailey
# Processing Record 50 of Set 14 | christchurch
# Processing Record 1 of Set 15 | liverpool
# Processing Record 2 of Set 15 | bathsheba
# Processing Record 3 of Set 15 | le port
# Processing Record 4 of Set 15 | barra do garcas
# Processing Record 5 of Set 15 | ryotsu
# Processing Record 6 of Set 15 | mataram
# Processing Record 7 of Set 15 | izumo
# Processing Record 8 of Set 15 | mpika
# Processing Record 9 of Set 15 | kainantu
# Processing Record 10 of Set 15 | kailua
# Processing Record 11 of Set 15 | kuala terengganu
# Processing Record 12 of Set 15 | yeletskiy
# City not found. Skipping...
# Processing Record 13 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 14 of Set 15 | kapoeta
# Processing Record 15 of Set 15 | general roca
# Processing Record 16 of Set 15 | porto santo
# Processing Record 17 of Set 15 | canico
# Processing Record 18 of Set 15 | zarinsk
# Processing Record 19 of Set 15 | esmeraldas
# Processing Record 20 of Set 15 | mananjary
# Processing Record 21 of Set 15 | uni
# Processing Record 22 of Set 15 | yulara
# Processing Record 23 of Set 15 | sobolevo
# Processing Record 24 of Set 15 | arvika
# Processing Record 25 of Set 15 | pitimbu
# Processing Record 26 of Set 15 | noshiro
# Processing Record 27 of Set 15 | waipawa
# Processing Record 28 of Set 15 | rock sound
# Processing Record 29 of Set 15 | uvira
# Processing Record 30 of Set 15 | palu
# Processing Record 31 of Set 15 | rio grande
# Processing Record 32 of Set 15 | pavino
# Processing Record 33 of Set 15 | palpa
# Processing Record 34 of Set 15 | mantua
# Processing Record 35 of Set 15 | mpongwe
# Processing Record 36 of Set 15 | luebo
# Processing Record 37 of Set 15 | aki
# Processing Record 38 of Set 15 | maunabo
# Processing Record 39 of Set 15 | coahuayana
# Processing Record 40 of Set 15 | mahajanga
# Processing Record 41 of Set 15 | fairview
# Processing Record 42 of Set 15 | gavle
# Processing Record 43 of Set 15 | cairns
# Processing Record 44 of Set 15 | tongliao
# Processing Record 45 of Set 15 | contramaestre
# Processing Record 46 of Set 15 | kisanga
# Processing Record 47 of Set 15 | forssa
# Processing Record 48 of Set 15 | cozumel
# Processing Record 49 of Set 15 | noumea
# Processing Record 50 of Set 15 | mayya
# Processing Record 1 of Set 16 | aranos
# Processing Record 2 of Set 16 | vulcan
# Processing Record 3 of Set 16 | abu dhabi
# Processing Record 4 of Set 16 | mukhen
# Processing Record 5 of Set 16 | rolla
# Processing Record 6 of Set 16 | beri
# Processing Record 7 of Set 16 | yatou
# Processing Record 8 of Set 16 | jieshi
# Processing Record 9 of Set 16 | palana
# Processing Record 10 of Set 16 | maluso
# Processing Record 11 of Set 16 | contamana
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
len(city_data)
# Out:
# 704

# %%
# exporting the data
df = pd.DataFrame(city_data)
df.to_csv('Weather_Database/Weather_Database.csv', index_label='City_ID')

# %%
df
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0       Escanaba      US  2021-12-06 17:40:13  45.7453  -87.0646     30.63
# 1      Stonewall      CA  2021-12-06 17:40:13  50.1344  -97.3268     -2.02
# 2    East London      ZA  2021-12-06 17:39:30 -33.0153   27.9116     68.94
# 3     Sao Filipe      CV  2021-12-06 17:35:59  14.8961  -24.4956     78.89
# 4        Rikitea      PF  2021-12-06 17:40:14 -23.1203 -134.9692     75.54
# ..           ...     ...                  ...      ...       ...       ...
# 699        Yatou      CN  2021-12-06 17:43:37  37.1500  122.3833     42.96
# 700       Jieshi      CN  2021-12-06 17:34:28  22.8134  115.8257     61.61
# 701       Palana      RU  2021-12-06 17:43:37  59.1167  159.9667     22.03
# 702       Maluso      PH  2021-12-06 17:43:38   6.5430  121.8753     79.23
# 703    Contamana      PE  2021-12-06 17:43:38  -7.3333  -75.0167     77.43
#
#      Humidity  Cloudiness  Wind Speed Current Description
# 0          75          90       20.71          light snow
# 1          81          19        9.57          few clouds
# 2          77          20       14.97          few clouds
# 3          62           2        7.94           clear sky
# 4          74          93        6.51     overcast clouds
# ..        ...         ...         ...                 ...
# 699        66          47       13.69    scattered clouds
# 700        74           3        9.86           clear sky
# 701        96         100        7.99                snow
# 702        83          87        7.05     overcast clouds
# 703        92         100        2.08     overcast clouds
#
# [704 rows x 10 columns]
